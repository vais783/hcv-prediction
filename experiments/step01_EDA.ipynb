# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r"C:\Users\vaish\OneDrive\Desktop\HEPATATIS C\hcv_data.zip\hcvdat0.csv"

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0       Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  \
# 0           1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93
# 1           2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17
# 2           3  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84
# 3           4  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33
# 4           5  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15
#
#    CHOL   CREA   GGT  PROT
# 0  3.23  106.0  12.1  69.0
# 1  4.80   74.0  15.6  76.5
# 2  5.20   86.0  33.2  79.3
# 3  4.74   80.0  33.8  75.7
# 4  4.32   76.0  29.9  68.7

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Category', 'Age', 'Sex', 'ALB', 'ALP', 'ALT', 'AST',
#        'BIL', 'CHE', 'CHOL', 'CREA', 'GGT', 'PROT'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  615 non-null    int64
#  1   Category    615 non-null    object
#  2   Age         615 non-null    int64
#  3   Sex         615 non-null    object
#  4   ALB         614 non-null    float64
#  5   ALP         597 non-null    float64
#  6   ALT         614 non-null    float64
#  7   AST         615 non-null    float64
#  8   BIL         615 non-null    float64
#  9   CHE         615 non-null    float64
#  10  CHOL        605 non-null    float64
#  11  CREA        615 non-null    float64
#  12  GGT         615 non-null    float64
#  13  PROT        614 non-null    float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 67.4+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0         Age         ALB         ALP         ALT         AST  \
# count  615.000000  615.000000  614.000000  597.000000  614.000000  615.000000
# mean   308.000000   47.408130   41.620195   68.283920   28.450814   34.786341
# std    177.679487   10.055105    5.780629   26.028315   25.469689   33.090690
# min      1.000000   19.000000   14.900000   11.300000    0.900000   10.600000
# 25%    154.500000   39.000000   38.800000   52.500000   16.400000   21.600000
# 50%    308.000000   47.000000   41.950000   66.200000   23.000000   25.900000
# 75%    461.500000   54.000000   45.200000   80.100000   33.075000   32.900000
# max    615.000000   77.000000   82.200000  416.600000  325.300000  324.000000
#
#               BIL         CHE        CHOL         CREA         GGT        PROT
# count  615.000000  615.000000  605.000000   615.000000  615.000000  614.000000
# mean    11.396748    8.196634    5.368099    81.287805   39.533171   72.044137
# ...

# %%
df = df.drop(columns=["Unnamed: 0"])
df.columns
# Out:
# Index(['Category', 'Age', 'Sex', 'ALB', 'ALP', 'ALT', 'AST', 'BIL', 'CHE',
#        'CHOL', 'CREA', 'GGT', 'PROT'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Category     0
# Age          0
# Sex          0
# ALB          1
# ALP         18
# ALT          1
# AST          0
# BIL          0
# CHE          0
# CHOL        10
# CREA         0
# GGT          0
# PROT         1
# dtype: int64

# %%
df["ALP"] = df["ALP"].fillna(df["ALP"]).mean()
df["ALB"] = df["ALB"].fillna(df["ALB"]).mean()
df["PROT"] = df["PROT"].fillna(df["PROT"]).mean()
df["CHOL"] = df["CHOL"].fillna(df["CHOL"]).mean()
df["ALT"] = df["ALT"].fillna(df["ALT"]).mean()

# %%
df.isnull().sum()
# Out:
# Category    0
# Age         0
# Sex         0
# ALB         0
# ALP         0
# ALT         0
# AST         0
# BIL         0
# CHE         0
# CHOL        0
# CREA        0
# GGT         0
# PROT        0
# dtype: int64

# %%
df.describe()
# Out:
#               Age         ALB        ALP         ALT         AST         BIL  \
# count  615.000000  615.000000  615.00000  615.000000  615.000000  615.000000
# mean    47.408130   41.620195   68.28392   28.450814   34.786341   11.396748
# std     10.055105    0.000000    0.00000    0.000000   33.090690   19.673150
# min     19.000000   41.620195   68.28392   28.450814   10.600000    0.800000
# 25%     39.000000   41.620195   68.28392   28.450814   21.600000    5.300000
# 50%     47.000000   41.620195   68.28392   28.450814   25.900000    7.300000
# 75%     54.000000   41.620195   68.28392   28.450814   32.900000   11.200000
# max     77.000000   41.620195   68.28392   28.450814  324.000000  254.000000
#
#               CHE          CHOL         CREA         GGT        PROT
# count  615.000000  6.150000e+02   615.000000  615.000000  615.000000
# mean     8.196634  5.368099e+00    81.287805   39.533171   72.044137
# std      2.205657  8.889014e-16    49.756166   54.661071    0.000000
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df["Category"] = le.fit_transform(df["Category"])
df["Age"] = le.fit_transform(df["Age"])
df["Sex"] = le.fit_transform(df["Sex"])
df["ALB"] = le.fit_transform(df["ALB"])
df["ALP"] = le.fit_transform(df["ALP"])
df["ALT"] = le.fit_transform(df["ALT"])
df["AST"] = le.fit_transform(df["AST"])
df["BIL"] = le.fit_transform(df["BIL"])
df["CHE"] = le.fit_transform(df["CHE"])
df["CHOL"] = le.fit_transform(df["CHOL"])
df["CREA"] = le.fit_transform(df["CREA"])
df["GGT"] = le.fit_transform(df["GGT"])
df["PROT"] = le.fit_transform(df["PROT"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  615 non-null    int64
#  1   Age       615 non-null    int64
#  2   Sex       615 non-null    int64
#  3   ALB       615 non-null    int64
#  4   ALP       615 non-null    int64
#  5   ALT       615 non-null    int64
#  6   AST       615 non-null    int64
#  7   BIL       615 non-null    int64
#  8   CHE       615 non-null    int64
#  9   CHOL      615 non-null    int64
#  10  CREA      615 non-null    int64
#  11  GGT       615 non-null    int64
#  12  PROT      615 non-null    int64
# dtypes: int64(13)
# memory usage: 62.6 KB

# %%
df.corr()
# Out:
#           Category       Age       Sex  ALB  ALP  ALT       AST       BIL  \
# Category  1.000000  0.110175  0.060657  NaN  NaN  NaN  0.598506  0.450253
# Age       0.110175  1.000000 -0.024264  NaN  NaN  NaN  0.091558  0.022987
# Sex       0.060657 -0.024264  1.000000  NaN  NaN  NaN  0.282619  0.244514
# ALB            NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# ALP            NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# ALT            NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# AST       0.598506  0.091558  0.282619  NaN  NaN  NaN  1.000000  0.397748
# BIL       0.450253  0.022987  0.244514  NaN  NaN  NaN  0.397748  1.000000
# CHE      -0.246700 -0.063028  0.194517  NaN  NaN  NaN  0.033880 -0.118944
# CHOL           NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# CREA     -0.102316 -0.042499  0.485657  NaN  NaN  NaN  0.095246  0.171181
# GGT       0.460043  0.113661  0.287496  NaN  NaN  NaN  0.539074  0.258913
# ...

# %%
plt.figure(figsize=(12, 9))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
sns.countplot(x = "Category", data = df)
plt.show()

# %%
df["Category"].value_counts()
# Out:
# Category
# 0    533
# 4     30
# 2     24
# 3     21
# 1      7
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Category', 'Age', 'Sex', 'ALB', 'ALP', 'ALT', 'AST', 'BIL', 'CHE',
#        'CHOL', 'CREA', 'GGT', 'PROT'],
#       dtype='object')

# %%
X = df.drop("Category", axis=1)  # input features
y = df["Category"]               # target/output

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X,y = smote.fit_resample(X, y)

# %%
df.columns
# Out:
# Index(['Category', 'Age', 'Sex', 'ALB', 'ALP', 'ALT', 'AST', 'BIL', 'CHE',
#        'CHOL', 'CREA', 'GGT', 'PROT'],
#       dtype='object')

# %%
sns.countplot( x = "Category", data = df)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(random_state=42, max_iter = 1000)

lr_model = lr.fit(X_train, y_train)
# Out:
# c:\Users\vaish\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
lr_pred = lr_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(classification_report(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       107
#            1       0.00      0.00      0.00         1
#            2       0.75      0.60      0.67         5
#            3       0.50      0.50      0.50         4
#            4       1.00      0.83      0.91         6
#
#     accuracy                           0.94       123
#    macro avg       0.64      0.58      0.61       123
# weighted avg       0.94      0.94      0.94       123
